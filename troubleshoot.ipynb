# %%
# import matplotlib
# matplotlib.use('module://matplotlib_inline.backend_inline')

# %%
# import matplotlib
# print(matplotlib.get_backend())

# %%
# import matplotlib.pyplot as plt
# import matplotlib
#
# plt.close('all')  # Explicitly close all figures before switching backends
# matplotlib.use('module://matplotlib_inline.backend_inline')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure()  # Create a new figure to ensure no previous plots interfere
plt.plot(x, y, label="Sine Wave")
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure()
plt.plot(x, y, label="Sine Wave")
plt.legend()
plt.show()

# %%
# %matplotlib inline

import numpy as np
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return dot(de_mean(x), de_mean(y)) / (n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# -0.14259731312158289

# %%
import numpy as np
import matplotlib.pyplot as plt

def de_mean(x):
    xmean = np.mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return np.dot(de_mean(x), de_mean(y)) / (n-1)

# Generate data
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

# Close all previous figures
plt.close('all')

# Create the scatter plot properly
plt.figure(figsize=(8, 6))
plt.scatter(pageSpeeds, purchaseAmount, alpha=0.5, edgecolors="k")
plt.xlabel("Page Speeds")
plt.ylabel("Purchase Amount")
plt.title("Scatter Plot of Page Speeds vs Purchase Amount")
plt.show()

# Compute covariance
print(covariance(pageSpeeds, purchaseAmount))
# Out:
# 0.37119653514599427

# %%
import matplotlib
print(matplotlib.get_backend())
# Out:
# inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label="Sine Wave")
plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Test Plot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data
x = np.random.normal(3.0, 1.0, 1000)
y = np.random.normal(50.0, 10.0, 1000)

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.5, edgecolors="k")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Test Scatter Plot")
plt.show()

# %%
# for Mac
# import matplotlib
# matplotlib.use('TkAgg')  # Try TkAgg backend

# %matplotlib inline

import numpy as np
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return dot(de_mean(x), de_mean(y)) / (n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# 0.411137459641053

# %%
# Out:
# inline
